# %%
#Creating a Dictionary:
country_code = {'India': 'in', 'Canada': 'ca', 'Europe': 'eu'}
print(country_code)
len(country_code)
if country_code:
    print('country_code is not empty')
else:
    pirnt('country_code is empty')
    
#Accessing Dictionaries:
days_per_month = {'January': 31, 'February': 28, 'March': 31}

for month, days in days_per_month.items():
    print(month,days)
    
for month in days_per_month.keys():
    print(month)
    
for days in days_per_month.values():
    print(days)
    
month_view = days_per_month.keys()
print(month_view)

days_per_month['April'] = 30
print(month_view)

#Creating List From Dictionary:
print(list(days_per_month))
print(list(days_per_month.keys()))
print(list(days_per_month.values()))
print(list(days_per_month.items()))
#******************************************************    
    
#Dictionary Modification
roman_num = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'X': 100}
print('Number is', roman_num['V'])

#Adding new Key, value pair:
roman_num['L'] = 50
print(roman_num)

#Updating/inserting Dictionary
country_codes = {}
country_codes.update({'Africa':'az'})
country_codes.update(Australia = 'au')
print(country_codes)


#Replacing existing value:
roman_num['V'] ='five'
print(roman_num)

#Removing Key Val:
del roman_num['V']
print(roman_num)

#Popping Value:
KEY = roman_num.pop('II')
print(roman_num)
print(KEY)

#Getting value from Dictionary using GET Method: To avoid KeyError if no value fount returns NONE
print(roman_num.get('V'))  #None
print(roman_num.get('V', "V is missng"))
print(roman_num.get('I'))

#in operator to check if key is in dictionary:
print('V' in roman_num)
print('V' not in roman_num)

#Sorting Dictionaries:
print(sorted(days_per_month.keys()))


#Dictionary Comparision:
days_per_month = {'January': 31, 'February': 28, 'March': 31}
days_per_month2 = {'May': 31, 'June': 30, 'July': 31}
days_per_month3 = {'February': 28, 'March': 31, 'January': 31}
if days_per_month == days_per_month2:
    print ('True')
else:
    print('False')

if days_per_month == days_per_month3:
    print ('True')
else:
    print('False')
    
#Dictionary Comprehension:
#Swaping key value pairs
roman_nums1 = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5}
roman_nums2= {num:rom for rom,num in roman_nums1.items()}
print(roman_nums2)
#Grade Calc
grades ={'keval': [49.55,89], 'niku': [22,98,77]}
grades_average = {key:sum(grad)/len(grad) for key, grad in grades.items()}
print(grades_average)


    
#Notes:
#Dictionary are unordered, homogenous mutable collection of data which maps unique keys to its values.
#Keys in Dictionaries must be unique and the values used as the key must be immutable data type. 
#Values in Dictionaries can be mutable or immutable.
#len() counts the key value pair in Dictionary.
#Dict_name.items() where items() returns each key value pair in Dictionary as tuple containing list and each tuple were unpacked into respective for loop variable.
#Dict_name.keys() where keys() return each key in Dictionary using for loop.
#Dict_name.values() where values() return each values in Dictionary using for loop.
#Remember always assume that a dictionary is an unordered collection of key value pairs and process it accordingly. 
#So for example, if you wanted to make sure that the names of the keys were displayed in an alphabetical order,
###then you would probably want to obtain the collection of keys first, sort it alphabetically, 
####then iterate through that and obtain each corresponding value to display the key value pairs.
#For Dictionary, key is provided in [] to get the value instead of index number. So keys are used to access the values in Dictionary
#GET is used to avoid Exception KeyError when the key is missing in the dictionary.
#If you call GET with a key, and there is no corresponding key value pair in the dictionary, 
###GET returns the Python constant none, and iPython displays nothing for that constant.
# items(), keys(), values() in all three of these methods' cases, what's really being returned is what's known as a dictionary view. 
###A dictionary view is effectively a window into the dictionary so you're looking at that dictionary's data, 
#####and if you modify the dictionary after you acquire the view, the next time you iterate through the view, you'll see the modified contents
#you can pass it any collection that contains elements with two values in them. So for instance, if I had a list that contained tuples,
####in which each tuple had two elements, the first element of the tuple would be processed as the key, 
####and the second element of the tuple would be processed as the value, so I could pass a list of tuples to the update method,
####and it will walk through that list, pick off each tuple and separate it into a key and a value,
####and then insert and/or update those elements as well.
#Dictionary Comprehension provide a convenient notation for creating entirely new dictionaries, typically from existing dictionaries.
# Out:
# {'India': 'in', 'Canada': 'ca', 'Europe': 'eu'}
# country_code is not empty
# January 31
# February 28
# March 31
# January
# February
# March
# 31
# 28
# 31
# dict_keys(['January', 'February', 'March'])
# dict_keys(['January', 'February', 'March', 'April'])
# ['January', 'February', 'March', 'April']
# ['January', 'February', 'March', 'April']
# [31, 28, 31, 30]
# [('January', 31), ('February', 28), ('March', 31), ('April', 30)]
# Number is 5
# {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'X': 100, 'L': 50}
# {'Africa': 'az', 'Australia': 'au'}
# {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 'five', 'X': 100, 'L': 50}
# {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'X': 100, 'L': 50}
# {'I': 1, 'III': 3, 'IV': 4, 'X': 100, 'L': 50}
# 2
# None
# V is missng
# 1
# False
# True
# ['April', 'February', 'January', 'March']
# False
# True
# {1: 'I', 2: 'II', 3: 'III', 4: 'IV', 5: 'V'}
# {'keval': 69.275, 'niku': 65.66666666666667}

# %%
dicto={'keval':1, 'Keval':2}
print(dicto)
# Out:
# {'keval': 1, 'Keval': 2}
